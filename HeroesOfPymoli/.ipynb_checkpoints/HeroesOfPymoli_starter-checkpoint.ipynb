# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)
purchase_data
# Out:
#      Purchase ID               SN  Age                 Gender  Item ID  \
# 0              0          Lisim78   20                   Male      108
# 1              1      Lisovynya38   40                   Male      143
# 2              2       Ithergue48   24                   Male       92
# 3              3    Chamassasya86   24                   Male      100
# 4              4        Iskosia90   23                   Male      131
# 5              5          Yalae81   22                   Male       81
# 6              6        Itheria73   36                   Male      169
# 7              7      Iskjaskst81   20                   Male      162
# 8              8        Undjask33   22                   Male       21
# 9              9      Chanosian48   35  Other / Non-Disclosed      136
# 10            10        Inguron55   23                   Male       95
# 11            11     Haisrisuir60   23                   Male      162
# ...

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
player_count = purchase_data['SN'].nunique()
print(f"There are {player_count} players")
# Out:
# There are 576 players

# %%
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
unique_items = purchase_data['Item ID'].nunique()

average_price = purchase_data['Price'].mean()

num_purchases = purchase_data['Purchase ID'].count()

total_revenue = purchase_data['Price'].sum()

summary_df = pd.DataFrame({"Summary": ['Player Count', "Unique Items", "Average Price/Purchase", "Total Number of Purchases", "Total Revenue"],
    "Value": [player_count, unique_items, average_price, num_purchases, total_revenue]})
summary_df
# Out:
#                      Summary        Value
# 0               Player Count   576.000000
# 1               Unique Items   183.000000
# 2     Average Price/Purchase     3.050987
# 3  Total Number of Purchases   780.000000
# 4              Total Revenue  2379.770000

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
percent_group = purchase_data.groupby('Gender')

summary_gender = percent_group['Purchase ID'].count()
summary_gender
# Out:
# Gender
# Female                   113
# Male                     652
# Other / Non-Disclosed     15
# Name: Purchase ID, dtype: int64

# %%
male_gender = purchase_data[purchase_data["Gender"] == "Male"]
male_gender_count = male_gender['SN'].nunique()

female_gender = purchase_data[purchase_data["Gender"] == "Female"]
female_gender_count = female_gender['SN'].nunique()

other_gender = purchase_data[purchase_data["Gender"] == "Other / Non-Disclosed"]
other_gender_count = other_gender['SN'].nunique()

male_percentage = male_gender_count / player_count
female_percentage = female_gender_count / player_count 
other_percentage = other_gender_count / player_count

# %%
gender_summary_df = pd.DataFrame({"Gender": ['Male', "Female", "Other / Non-Disclosed"],
    "% of gamers": [male_percentage*100, female_percentage*100, other_percentage*100]})
gender_summary_df
# Out:
#                   Gender  % of gamers
# 0                   Male    84.027778
# 1                 Female    14.062500
# 2  Other / Non-Disclosed     1.909722

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
male_purchase_count = male_gender['Purchase ID'].nunique()
female_purchase_count = female_gender['Purchase ID'].nunique()
other_purchase_count = other_gender['Purchase ID'].nunique()

male_avg_price = male_gender['Price'].mean()
female_avg_price = female_gender['Price'].mean()
other_avg_price = other_gender['Price'].mean()

male_total_price = male_gender['Price'].sum()
female_total_price = female_gender['Price'].sum()
other_total_price = other_gender['Price'].sum()

male_sort = male_gender.groupby('SN')
male_avg_ptran = male_sort['Price'].mean()
female_sort = female_gender.groupby('SN')
female_avg_ptran = female_sort['Price'].mean()
other_sort = other_gender.groupby('SN')
other_avg_ptran = other_sort['Price'].mean()

male_total = male_total_price/male_purchase_count
female_total = female_total_price/female_purchase_count
other_total = other_total_price/other_purchase_count


purchasing_analysis_df = pd.DataFrame({"Gender": ['Male', "Female", "Ohter / Non-Disclosed"],
    "Purchase Count": [male_purchase_count, female_purchase_count, other_purchase_count],
     "Average Purchase Price": [male_avg_price, female_avg_price, other_avg_price],
    "Total Purchase Value": [male_total_price, female_total_price, other_total_price],
    "Average Purchase Total per Person by Gender": [male_total,female_total,other_total]
                                      })
purchasing_analysis_df
# Out:
#                   Gender  Purchase Count  Average Purchase Price  \
# 0                   Male             652                3.017853
# 1                 Female             113                3.203009
# 2  Ohter / Non-Disclosed              15                3.346000
#
#    Total Purchase Value  Average Purchase Total per Person by Gender
# 0               1967.64                                     3.017853
# 1                361.94                                     3.203009
# 2                 50.19                                     3.346000

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
bins = [0,10,14,19,24,29,34,39,40]

group_names = ["<10","10-14","14-19","19-24","24-29","29-34","34-39","40+"]

age_demo = purchase_data
age_demo["Age Group"] = pd.cut(age_demo["Age"], bins, labels=group_names)
age_summary = age_demo.groupby("Age Group")
purchase_count = age_summary['Purchase ID'].count()
age_group_df = pd.DataFrame(purchase_count).rename(columns={"Purchase ID":"# of Players"})

age_group_df
# Out:
#            # of Players
# Age Group
# <10                  32
# 10-14                19
# 14-19               136
# 19-24               365
# 24-29               101
# 29-34                73
# 34-39                41
# 40+                   6

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purchase_count = age_summary['Purchase ID'].count()
avg_per_price = age_summary['Price'].mean()
total_purchase_price  = age_summary['Price'].sum()

avg_per_purchase = total_purchase_price/purchase_count
avg_per_purchase

new_df = pd.DataFrame(purchase_count)
avg_df = pd.DataFrame(avg_per_price)
total_df = pd.DataFrame(total_purchase_price)
avg_df = pd.DataFrame(avg_per_purchase)
combined_df = pd.merge(new_df, avg_df, how='outer', on='Age Group')
combined_df = pd.merge(combined_df, total_df, how='outer', on='Age Group')
combined_df = pd.merge(combined_df, avg_df, how='outer', on='Age Group')
combined_df = combined_df.rename(columns={"Purchase ID":"Purchase Count",
                                          "0_x":"Average Purchase Price",
                                          "Price":"Total Purchase Value",
                                         "0_y":"Average Purchase Total per Person by Age Group"})
combined_df
# Out:
#            Purchase Count  Average Purchase Price  Total Purchase Value  \
# Age Group
# <10                    32                3.405000                108.96
# 10-14                  19                2.681579                 50.95
# 14-19                 136                3.035956                412.89
# 19-24                 365                3.052219               1114.06
# 24-29                 101                2.900990                293.00
# 29-34                  73                2.931507                214.00
# 34-39                  41                3.601707                147.67
# 40+                     6                2.785000                 16.71
#
#            Average Purchase Total per Person by Age Group
# Age Group
# <10                                              3.405000
# 10-14                                            2.681579
# 14-19                                            3.035956
# 19-24                                            3.052219
# ...

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
top_spender_data = purchase_data.groupby(["SN"])

SN_purchase_count = top_spender_data['Purchase ID'].count()
SN_purchase_count_df = pd.DataFrame(SN_purchase_count)

SN_purchase_average = top_spender_data['Price'].mean()
SN_purchase_average_df = pd.DataFrame(SN_purchase_average)


SN_purchase_amount = top_spender_data['Price'].sum()

SN_purchase_amount_df = pd.DataFrame(SN_purchase_amount)
SN_purchase_amount_df = SN_purchase_amount_df.sort_values("Price", ascending=False)

top_spender_df = pd.merge(SN_purchase_amount_df_sorted,SN_purchase_count_df,how='outer',on='SN')
top_spender_df = pd.merge(top_spender_df,SN_purchase_average_df,how='outer',on='SN')
top_spender_df = top_spender_df.rename(columns={"Total Amount Sent":"Total Amount Spent",
                                               "Purchase ID": "# of Purchases",
                                               "Price":"Average Amount Spent"})

top_spender_df.head(5)
# Out:
#              Total Amount Spent  # of Purchases  Average Amount Spent
# SN
# Lisosia93                 18.96               5              3.792000
# Idastidru52               15.45               4              3.862500
# Chamjask73                13.83               3              4.610000
# Iral74                    13.62               4              3.405000
# Iskadarya95               13.10               3              4.366667

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
most_pop_list = purchase_data[['Item ID','Item Name','Price','Purchase ID']].groupby(["Item Name","Item ID"])
item_list = most_pop_list['Item ID'].count()
pop_item_df = pd.DataFrame(item_list)
item_price = most_pop_list['Price'].sum()
item_price_df = pd.DataFrame(item_price)
item_id = most_pop_list['Item ID','Item Name']
item_id_df = pd.DataFrame(item_id)
item_price_df.head()

merge_df_1 = pd.merge(item_price_df,pop_item_df,how='outer',on='Item Name')
merge_df_1 = merge_df_1.rename(columns={"Item ID":"Total Purchases"})


#merge_df_2 = pd.merge(merge_df_1,item_id_df,how='outer',on='Item ID')

merge_df_1.head()
most_pop_list.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-425-d795c325c4de> in <module>
#      11 merge_df_1 = merge_df_1.rename(columns={"Item ID":"Total Purchases"})
#      12
# ---> 13 group_sort_list = item_list.sort_values('Total Purchases', ascending=False)
#      14
#      15 #merge_df_2 = pd.merge(merge_df_1,item_id_df,how='outer',on='Item ID')
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/series.py in sort_values(self, axis, ascending, inplace, kind, na_position)
#    2774         inplace = validate_bool_kwarg(inplace, 'inplace')
#    2775         # Validate the axis parameter
# -> 2776         self._get_axis_number(axis)
#    2777
#    2778         # GH 5856/5853
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     359                 pass
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
most_profitable_set = purchase_data.groupby(["Item ID"])


new_group_idea = purchase_data[['Item ID','Item Name','Price','Purchase ID']]
new_group_group = new_group_idea.groupby(["Item ID","Item Name","Price"])
newgroupid_df = pd.DataFrame(new_group_idea)
total = new_group_group['Price'].sum()

purchase_id_count = new_group_group['Purchase ID'].count()
purchase_id_count_df = pd.DataFrame(purchase_id_count)
total_df =pd.DataFrame(total) 
group_sort = purchase_id_count_df.sort_values('Purchase ID', ascending=False)
group_sort_df = pd.DataFrame(group_sort)
group_sort_df = group_sort_df.rename(columns={"Purchase ID":"Total Purchases"})

group_sort_df.head()
# Out:
#                                                             Total Purchases
# Item ID Item Name                                    Price
# 178     Oathbreaker, Last Hope of the Breaking Storm 4.23                12
# 145     Fiery Glass Crusader                         4.58                 9
# 108     Extraction, Quickblade Of Trembling Hands    3.53                 9
# 82      Nirvana                                      4.90                 9
# 19      Pursuit, Cudgel of Necromancy                1.02                 8
